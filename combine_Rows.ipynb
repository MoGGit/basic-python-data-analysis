# %% [markdown]
# <a href="https://colab.research.google.com/github/MoGGit/basic-python-data-analysis/blob/main/combine_Rows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings("ignore")


    # add your code hereimport pandas as pd
btc_bitflyer= pd.read_csv('https://drive.google.com/uc?export=download&id=1eIvrMKJ9FKqlrD3w_EWsJyPpSBZrmfhl')
btc_bitstamp=pd.read_csv('https://drive.google.com/uc?export=download&id=1ksNGCuBRxFU2mY4WftKZsjWvshh_BB6L')
btc_coinbase=pd.read_csv('https://drive.google.com/uc?export=download&id=1JZedP2K81eGZuIwMohL-ZCzsBiDM09kC')
btc_coincheck=pd.read_csv('https://drive.google.com/uc?export=download&id=1uZs-l060HtELe-0py-Tj0r6XAAjnVbS2')
combine_datas= btc_bitflyer.append(btc_bitstamp)
combine_datas= combine_datas.append(btc_coinbase)
combine_datas= combine_datas.append(btc_coincheck)
combine_datas.columns
# Out:
# Index(['id', 'open', 'high', 'low', 'close', 'volume_btc', 'volume_currency',
#        'weighted_price', 'timestamp'],
#       dtype='object')

# %%
combine_datas.drop('id',axis=1,inplace=True)

# %%
# Out:
# Index(['open', 'high', 'low', 'close', 'volume_btc', 'volume_currency',
#        'weighted_price', 'timestamp'],
#       dtype='object')

# %%
vis=sns.pairplot(combine_datas)
